# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Bidirectional, Attention, BatchNormalization, Input
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras_tuner import RandomSearch
from tensorflow.keras.callbacks import EarlyStopping
from statsmodels.tsa.arima.model import ARIMA, ARIMAResults
from scipy.stats import chi2
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import pandas_datareader.data as web
import datetime
import shap

# %%
ticker = "AAPL"
macro_indicators = ["GDP", "CPIAUCSL", "UNRATE", "FEDFUNDS", "GS10", "INDPRO", "PPIACO", "RSXFS", "HOUST", "PSAVERT"]

# %%
def fetch_data(ticker):
    data = {}
    stock = yf.Ticker(ticker)
    data[ticker] = stock.history(period="max")[['Open', 'High', 'Low', 'Close', 'Volume']]
    return data

def fetch_macro_data(macro_indicators):
    start = datetime.datetime(1992, 1, 1)
    end = datetime.datetime.now()
    return {ind: web.DataReader(ind, 'fred', start, end) for ind in macro_indicators}

# %%
def preprocess_data(df):
    df.fillna(method='ffill',inplace=True)
    df.fillna(method='bfill',inplace=True)
    return df

# %%
def create_features(df,ticker):
    df[f'{ticker}_LogReturn'] = np.log(df['Close'] / df['Close'].shift(1))
    df[f'{ticker}_RollingVolatility'] = df[f'{ticker}_LogReturn'].rolling(window=30).std()
    df[f'{ticker}_MaxDrawDown'] = df['Close']/ df['Close'].rolling(window=30).max()-1
    df[f'{ticker}_Momentum'] = df['Close'].diff(10)
    df[f'{ticker}_RSI'] = 100 - (100 / (1+df['Close'].pct_change().rolling(14).mean()/ df['Close'].pct_change().rolling(14).std())) 


    df['Year'] = df.index.year
    df['Month'] = df.index.month
    df['Week'] = df.index.isocalendar().week
    df['DayOfWeek'] = df.index.dayofweek
    return df

# %%
stock_data = fetch_data(ticker)[ticker]

# %%
# Baseline models
def arima_baseline(y_train, y_test):
    model = ARIMA(y_train, order=(5,1,0)).fit
    return model.ARIMAResults.forecast(steps=len(y_test))

def linear_regression_baseline(X_train, X_test, y_train):
    model = LinearRegression()
    model.fit(X_train, y_train)
    return model.predict(X_test)

# %%
def evaluate_model(y_true, y_pred):
    print(f"Mean Absolute Error: f{mean_absolute_error(y_pred,y_true)}")
    print(f"Mean Squared Error: f{mean_squared_error(y_pred,y_true)}")
    print(f"R-Squared Score: f{r2_score(y_pred,y_true)}")

# %%
def build_lstm_model(input_shape):
    print(f"inputshape: {input_shape}")
    inputs = Input(shape=(input_shape[0], input_shape[1]))

    lstm_out = Bidirectional(LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.2))(inputs)
    attention = Attention()([lstm_out, lstm_out])

    lstm_out = LSTM(32, return_sequences=False, dropout=0.2, recurrent_dropout=0.2)(attention)
    lstm_out = BatchNormalization()(lstm_out)

    dense_out = Dense(32, activation="relu")(lstm_out)
    dense_out = Dropout(0.3)(dense_out)
    dense_out = Dense(16, activation="relu")(dense_out)

    output = Dense(1)(dense_out)

    model = Model(inputs=inputs, outputs=output)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")

    return model

# %%
def backtest_strategy(y_test, y_pred, asset_name):
    if isinstance(y_pred, pd.Series):
        y_pred_series = y_pred  
    else:
        y_pred_series = pd.Series(y_pred.flatten(), index=y_test.index)  
    plt.figure(figsize=(12,6))
    plt.plot(y_test.index, y_test, label='Actual', color='blue')
    plt.plot(y_pred_series.index, y_pred_series, label='Predicted', color='red', linestyle='dashed')
    plt.xlabel("Time")
    plt.ylabel("Log Return")
    plt.title(f"{asset_name} Model Backtest Performance")
    plt.legend()
    plt.show()

# %%
stock_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098726    0.099155    0.098726    0.098726
# 1980-12-15 00:00:00-05:00    0.094005    0.094005    0.093575    0.093575
# 1980-12-16 00:00:00-05:00    0.087136    0.087136    0.086707    0.086707
# 1980-12-17 00:00:00-05:00    0.088853    0.089282    0.088853    0.088853
# 1980-12-18 00:00:00-05:00    0.091429    0.091858    0.091429    0.091429
# ...                               ...         ...         ...         ...
# 2025-04-22 00:00:00-04:00  196.119995  201.589996  195.970001  199.740005
# 2025-04-23 00:00:00-04:00  206.000000  208.000000  202.800003  204.600006
# 2025-04-24 00:00:00-04:00  204.889999  208.830002  202.940002  208.369995
# 2025-04-25 00:00:00-04:00  206.369995  209.750000  206.199997  209.279999
# 2025-04-28 00:00:00-04:00  210.059998  211.500000  207.460007  210.139999
#
#                               Volume
# Date
# 1980-12-12 00:00:00-05:00  469033600
# 1980-12-15 00:00:00-05:00  175884800
# 1980-12-16 00:00:00-05:00  105728000
# 1980-12-17 00:00:00-05:00   86441600
# 1980-12-18 00:00:00-05:00   73449600
# ...                              ...
# 2025-04-22 00:00:00-04:00   52976400
# 2025-04-23 00:00:00-04:00   52929200
# 2025-04-24 00:00:00-04:00   47311000
# 2025-04-25 00:00:00-04:00   38198600
# 2025-04-28 00:00:00-04:00   37235797
#
# [11184 rows x 5 columns]

# %%
macro_data = fetch_macro_data(macro_indicators)

# %%
tidy_series = []
for name, df_or_ser in macro_data.items():
    s = (df_or_ser.squeeze().rename(name).to_frame())
    s.index = pd.to_datetime(s.index).tz_localize(None)
    tidy_series.append(s)

# %%
macro_df = (pd.concat(tidy_series, axis=1).sort_index())

# %%
macro_df
# Out:
#                  GDP  CPIAUCSL  UNRATE  FEDFUNDS  GS10    INDPRO   PPIACO  \
# DATE
# 1992-01-01  6363.102   138.300     7.3      4.03  7.03   61.4823  115.600
# 1992-02-01       NaN   138.600     7.4      4.06  7.34   61.9192  116.000
# 1992-03-01       NaN   139.100     7.4      3.98  7.54   62.4403  116.100
# 1992-04-01  6470.763   139.400     7.4      3.73  7.48   62.9199  116.300
# 1992-05-01       NaN   139.700     7.6      3.82  7.39   63.1268  117.200
# ...              ...       ...     ...       ...   ...       ...      ...
# 2024-11-01       NaN   316.449     4.2      4.64  4.36  101.9619  253.211
# 2024-12-01       NaN   317.603     4.1      4.48  4.39  103.1177  253.434
# 2025-01-01       NaN   319.086     4.0      4.33  4.63  103.3418  257.387
# 2025-02-01       NaN   319.775     4.1      4.33  4.45  104.2202  259.805
# 2025-03-01       NaN   319.615     4.2      4.33  4.28  103.8892  258.837
#
#              RSXFS  HOUST  PSAVERT
# DATE
# 1992-01-01  142419   1176      9.5
# 1992-02-01  142584   1250      9.8
# 1992-03-01  142120   1297      9.7
# 1992-04-01  143659   1099      9.8
# 1992-05-01  144239   1214      9.8
# ...            ...    ...      ...
# 2024-11-01  616833   1305      3.7
# 2024-12-01  622396   1526      3.3
# 2025-01-01  615973   1361      4.3
# 2025-02-01  617125   1494      4.6
# 2025-03-01  625678   1324      NaN
#
# [399 rows x 10 columns]

# %%
stock_data.index = pd.to_datetime(stock_data.index).tz_localize(None)
macro_df.index = pd.to_datetime(macro_df.index)
full_idx = pd.date_range(stock_data.index.min(), stock_data.index.max(), freq='D')
macro_daily = macro_df.reindex(full_idx).ffill()

# %%
merged = stock_data.join(macro_daily,how='left')

# %%
merged
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.098726    0.099155    0.098726    0.098726  469033600
# 1980-12-15    0.094005    0.094005    0.093575    0.093575  175884800
# 1980-12-16    0.087136    0.087136    0.086707    0.086707  105728000
# 1980-12-17    0.088853    0.089282    0.088853    0.088853   86441600
# 1980-12-18    0.091429    0.091858    0.091429    0.091429   73449600
# ...                ...         ...         ...         ...        ...
# 2025-04-22  196.119995  201.589996  195.970001  199.740005   52976400
# 2025-04-23  206.000000  208.000000  202.800003  204.600006   52929200
# 2025-04-24  204.889999  208.830002  202.940002  208.369995   47311000
# 2025-04-25  206.369995  209.750000  206.199997  209.279999   38198600
# 2025-04-28  210.059998  211.500000  207.460007  210.139999   37235797
#
#                   GDP  CPIAUCSL  UNRATE  FEDFUNDS  GS10    INDPRO   PPIACO  \
# Date
# 1980-12-12        NaN       NaN     NaN       NaN   NaN       NaN      NaN
# 1980-12-15        NaN       NaN     NaN       NaN   NaN       NaN      NaN
# 1980-12-16        NaN       NaN     NaN       NaN   NaN       NaN      NaN
# 1980-12-17        NaN       NaN     NaN       NaN   NaN       NaN      NaN
# 1980-12-18        NaN       NaN     NaN       NaN   NaN       NaN      NaN
# ...               ...       ...     ...       ...   ...       ...      ...
# 2025-04-22  29723.864   319.615     4.2      4.33  4.28  103.8892  258.837
# 2025-04-23  29723.864   319.615     4.2      4.33  4.28  103.8892  258.837
# 2025-04-24  29723.864   319.615     4.2      4.33  4.28  103.8892  258.837
# 2025-04-25  29723.864   319.615     4.2      4.33  4.28  103.8892  258.837
# 2025-04-28  29723.864   319.615     4.2      4.33  4.28  103.8892  258.837
#
#                RSXFS   HOUST  PSAVERT
# Date
# 1980-12-12       NaN     NaN      NaN
# 1980-12-15       NaN     NaN      NaN
# 1980-12-16       NaN     NaN      NaN
# 1980-12-17       NaN     NaN      NaN
# 1980-12-18       NaN     NaN      NaN
# ...              ...     ...      ...
# 2025-04-22  625678.0  1324.0      4.6
# 2025-04-23  625678.0  1324.0      4.6
# 2025-04-24  625678.0  1324.0      4.6
# 2025-04-25  625678.0  1324.0      4.6
# 2025-04-28  625678.0  1324.0      4.6
#
# [11184 rows x 15 columns]

# %%
full_df = preprocess_data(create_features(merged, ticker))
# Out:
# C:\Users\Rj\AppData\Local\Temp\ipykernel_29216\3014731629.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# C:\Users\Rj\AppData\Local\Temp\ipykernel_29216\3014731629.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace=True)

# %%
full_df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.098726    0.099155    0.098726    0.098726  469033600
# 1980-12-15    0.094005    0.094005    0.093575    0.093575  175884800
# 1980-12-16    0.087136    0.087136    0.086707    0.086707  105728000
# 1980-12-17    0.088853    0.089282    0.088853    0.088853   86441600
# 1980-12-18    0.091429    0.091858    0.091429    0.091429   73449600
# ...                ...         ...         ...         ...        ...
# 2025-04-22  196.119995  201.589996  195.970001  199.740005   52976400
# 2025-04-23  206.000000  208.000000  202.800003  204.600006   52929200
# 2025-04-24  204.889999  208.830002  202.940002  208.369995   47311000
# 2025-04-25  206.369995  209.750000  206.199997  209.279999   38198600
# 2025-04-28  210.059998  211.500000  207.460007  210.139999   37235797
#
#                   GDP  CPIAUCSL  UNRATE  FEDFUNDS  GS10  ...  PSAVERT  \
# Date                                                     ...
# 1980-12-12   6363.102   138.300     7.3      4.03  7.03  ...      9.5
# 1980-12-15   6363.102   138.300     7.3      4.03  7.03  ...      9.5
# 1980-12-16   6363.102   138.300     7.3      4.03  7.03  ...      9.5
# 1980-12-17   6363.102   138.300     7.3      4.03  7.03  ...      9.5
# 1980-12-18   6363.102   138.300     7.3      4.03  7.03  ...      9.5
# ...               ...       ...     ...       ...   ...  ...      ...
# 2025-04-22  29723.864   319.615     4.2      4.33  4.28  ...      4.6
# 2025-04-23  29723.864   319.615     4.2      4.33  4.28  ...      4.6
# 2025-04-24  29723.864   319.615     4.2      4.33  4.28  ...      4.6
# 2025-04-25  29723.864   319.615     4.2      4.33  4.28  ...      4.6
# 2025-04-28  29723.864   319.615     4.2      4.33  4.28  ...      4.6
#
#             AAPL_LogReturn  AAPL_RollingVolatility  AAPL_MaxDrawDown  \
# Date
# 1980-12-12       -0.053581                0.038979         -0.104166
# 1980-12-15       -0.053581                0.038979         -0.104166
# 1980-12-16       -0.076231                0.038979         -0.104166
# 1980-12-17        0.024449                0.038979         -0.104166
# 1980-12-18        0.028580                0.038979         -0.104166
# ...                    ...                     ...               ...
# 2025-04-22        0.033498                0.041959         -0.107865
# 2025-04-23        0.024040                0.041988         -0.086158
# 2025-04-24        0.018258                0.042054         -0.069320
# 2025-04-25        0.004358                0.041602         -0.065255
# 2025-04-28        0.004101                0.041471         -0.061414
#
#             AAPL_Momentum   AAPL_RSI  Year  Month  Week  DayOfWeek
# Date
# 1980-12-12       0.024896  21.062434  1980     12    50          4
# 1980-12-15       0.024896  21.062434  1980     12    51          0
# 1980-12-16       0.024896  21.062434  1980     12    51          1
# 1980-12-17       0.024896  21.062434  1980     12    51          2
# 1980-12-18       0.024896  21.062434  1980     12    51          3
# ...                   ...        ...   ...    ...   ...        ...
# 2025-04-22      18.279999 -11.472834  2025      4    17          1
# 2025-04-23      32.180008  -8.378403  2025      4    17          2
# 2025-04-24       9.519989   5.400709  2025      4    17          3
# 2025-04-25      18.860001  14.479172  2025      4    17          4
# 2025-04-28      11.990005  18.928568  2025      4    18          0
#
# [11184 rows x 24 columns]

# %%
def train_test_split_data(full_df, ticker):
    features = full_df.columns.difference([f'{ticker}_LogReturn'])
    X = full_df[features].values
    y = full_df[f'{ticker}_LogReturn'].values
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, shuffle=False)
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.fit_transform(X_test)
    return X_train_scaled,X_test_scaled, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(full_df.drop(columns=[f'{ticker}_LogReturn']), full_df[f'{ticker}_LogReturn'], test_size=0.2, shuffle=False)
input_shape = (X_train.shape[1],1)
model = build_lstm_model(input_shape)



X_train_reshaped = np.array(X_train, dtype=np.float32).reshape(X_train.shape[0], X_train.shape[1],1)
X_test_reshaped = np.array(X_test, dtype=np.float32).reshape(X_test.shape[0], X_test.shape[1],1)



history = model. fit(X_train_reshaped,np.array(y_train, dtype=np.float32),
                     epochs=50, batch_size=32 ,validation_split=0.2, 
                     callbacks =[EarlyStopping(monitor='val_loss',patience=5)])

y_pred = model.predict(X_test_reshaped)
#arima_pred = arima_baseline(y_train, y_test)
lr_pred = linear_regression_baseline(X_train, X_test, y_train)
# Out:
# inputshape: (23, 1)
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - loss: 0.0961 - val_loss: 3.2695e-04
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0071 - val_loss: 3.4847e-04
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0032 - val_loss: 2.8774e-04
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 0.0024 - val_loss: 3.1137e-04
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0016 - val_loss: 3.0481e-04
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0014 - val_loss: 2.7935e-04
# Epoch 7/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0014 - val_loss: 2.8068e-04
# Epoch 8/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0012 - val_loss: 3.2849e-04
# Epoch 9/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0012 - val_loss: 2.8610e-04
# Epoch 10/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0012 - val_loss: 3.1092e-04
# Epoch 11/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0011 - val_loss: 3.1100e-04
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step

# %%
print("comparision.....................")
print("LSTM model")
evaluate_model(y_test,y_pred)
# print("Arima model")
# evaluate_model(y_test,arima_pred)
print("Linear Regression model")
evaluate_model(y_test,lr_pred)



backtest_strategy(y_test,y_pred,ticker)
# backtest_strategy(y_test,arima_pred,f'{ticker} -ARIMA')
backtest_strategy(y_test,lr_pred,f'{ticker} -Linear Regression')
# Out:
# comparision.....................
# LSTM model
# Mean Absolute Error: f0.013670267701026462
# Mean Squared Error: f0.00037213835253530444
# R-Squared Score: f-1607.8958994142927
# Linear Regression model
# Mean Absolute Error: f0.07344029710582052
# Mean Squared Error: f0.014925681404717459
# R-Squared Score: f0.15619079694465232

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label = 'Training Loss', color = 'blue')
plt.plot(history.history['val_loss'], label = 'Validation Loss', color = 'red', linestyle='dashed')
plt.xlabel('Epoches')
plt.ylabel('Loss')
plt.title(f'Model training loss over time')
plt.legend()
plt.show()
